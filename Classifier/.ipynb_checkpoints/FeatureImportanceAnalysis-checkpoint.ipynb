# %%
import pandas as pd
import numpy as np

# %%
rf_df = pd.read_csv("/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/CRC_k7_DataAugmentation/kmer_BatchCorrected_bin_crc_adenomaORnormal_DataAugmentationfilter_TRUE_trans_clr_scale_RF_importance.csv",\
                   index_col=0)

# %%
row_means = rf_df.mean(axis=1)
row_means = row_means.sort_values(axis=0, ascending=False)

# %%
list(row_means.index).index("batch_labels_factor2")
# Out:
# 8188

# %%
rf_df
# Out:
#                              0         1         2         3         4  \
# AAAAAAA               0.000000  0.000000  0.000000  0.000000  0.000000
# AAAAAAC               0.000171  0.000000  0.000000  0.000000  0.000000
# AAAAAAG               0.000000  0.000000  0.000000  0.000000  0.000168
# AAAAAAT               0.000000  0.000000  0.000000  0.000000  0.000000
# AAAAACA               0.000000  0.000000  0.000000  0.000746  0.000000
# AAAAACC               0.000000  0.000000  0.000000  0.000000  0.000000
# AAAAACG               0.000000  0.000000  0.000000  0.000224  0.000000
# AAAAACT               0.000000  0.000000  0.000000  0.000000  0.000000
# AAAAAGA               0.000230  0.000000  0.000000  0.000000  0.000000
# AAAAAGC               0.000000  0.000000  0.000492  0.000000  0.000000
# AAAAAGG               0.000000  0.000000  0.000604  0.000909  0.000000
# AAAAAGT               0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
rf_df.sum(axis=0)
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    1.0
# 17    1.0
# 18    1.0
# 19    1.0
# 20    1.0
# 21    1.0
# 22    1.0
# 23    1.0
# 24    1.0
# 25    1.0
# 26    1.0
# 27    1.0
# 28    1.0
# 29    1.0
# 30    1.0
# 31    1.0
# 32    1.0
# 33    1.0
# 34    1.0
# 35    1.0
# 36    1.0
# 37    1.0
# 38    1.0
# 39    1.0
# 40    1.0
# 41    1.0
# 42    1.0
# 43    1.0
# 44    1.0
# 45    1.0
# 46    1.0
# 47    1.0
# 48    1.0
# 49    1.0
# dtype: float64
