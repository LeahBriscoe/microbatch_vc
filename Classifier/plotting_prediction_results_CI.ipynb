# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_folder = '/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/'
plot_folder = '/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/plots/'

# %%
file_names =[ 'otu_BatchCorrected_bmi_corrected_pearson_and_mse',
             'kmer_BatchCorrected_bmi_corrected_pearson_and_mse',
             'kmer_kmer_table_bmi_corrected_pearson_and_mse']



#['bmi_corrected_pearson_and_mse','bmi_corrected_pearson_and_mse']
    
# file_names =[ 'otu_BatchCorrected_antibiotic_classification_auc',
#              'kmer_BatchCorrected_antibiotic_classification_auc',
#              'kmer_kmer_table_antibiotic_classification_auc']
folder_names = ['AGP_otumatch_otu','AGP_otumatch_k7','AGP_otumatch_k7']#['AGP_healthymax_k6', 'AGP_healthymax_k7']
#['AGP_otumatch_otu','AGP_otumatch_k7','AGP_otumatch_k7']
#['AGP_healthymax_k6', 'AGP_healthymax_k7']
nice_names = ['OTU',"KMER","KMER"]#, 'KMER old batch correct','KMER MINERVA']

metric_word = 'pearson' #auc_all'#'
classifier = 'bmi_prediction'#' 'Naive Bayes' #
select_columns_bool = True
title = 'Pearson correlation of predicted body mass index (BMI)'#''AUC for prediction of antibiotic history'#''

# %%
df_metric = pd.DataFrame()

# %%
for f in range(len(file_names)):

    data_temp = pickle.load( open( data_folder + folder_names[f] +"/"+ file_names[f] + ".pkl" ,"rb"))
    #methods_lists.append([k for k in data1.keys()])   
    for k in data_temp:
        if metric_word == "auc_all":
            df_metric[nice_names[f] + str(k)] = pd.Series(data_temp[k][classifier][metric_word])
        else:
            df_metric[nice_names[f] + str(k)] = pd.Series(data_temp[k][metric_word])

# %%
df_metric
# Out:
#       OTUraw    OTUbmc  OTUComBat  OTUlimma  OTUclr_pca_regress_out_scale  \
# 0   0.069861  0.087074   0.103933  0.087076                      0.101097
# 1   0.028673  0.030624   0.028048  0.030731                      0.153262
# 2   0.071600  0.068041   0.077177  0.067915                      0.002697
# 3   0.079294  0.048391   0.066809  0.048461                      0.089125
# 4   0.095356  0.094011   0.098950  0.093846                      0.088556
# 5   0.069861  0.087074   0.103933  0.087076                      0.101097
# 6   0.028673  0.030624   0.028048  0.030731                      0.153262
# 7   0.071600  0.068041   0.077177  0.067915                      0.002697
# 8   0.079294  0.048391   0.066809  0.048461                      0.089125
# 9   0.095356  0.094011   0.098950  0.093846                      0.088556
# 10  0.069861  0.087074   0.103933  0.087076                      0.101097
# 11  0.028673  0.030624   0.028048  0.030731                      0.153262
# 12  0.071600  0.068041   0.077177  0.067915                      0.002697
# 13  0.079294  0.048391   0.066809  0.048461                      0.089125
# 14  0.095356  0.094011   0.098950  0.093846                      0.088556
# 15  0.069861  0.087074   0.103933  0.087076                      0.101097
# 16  0.028673  0.030624   0.028048  0.030731                      0.153262
# 17  0.071600  0.068041   0.077177  0.067915                      0.002697
# 15                         0.147287 -0.017020 -0.027577    0.008445
# 16                         0.040880 -0.053277 -0.075974    0.046453
# 17                         0.081571 -0.038462 -0.026583    0.039430
# 18                         0.092091  0.021934  0.039447   -0.000839
# 19                         0.133685 -0.038996  0.063233   -0.066015
# 20                         0.147287 -0.034283  0.069910    0.036771
# 21                         0.040880 -0.007703 -0.080084    0.030205
# 22                         0.081571 -0.022079  0.004644   -0.029601
# 23                         0.092091  0.084094  0.054536    0.051166
# 24                         0.133685  0.035116  0.035297   -0.016927
# 25                         0.147287  0.088423  0.074601    0.045990
# 26                         0.040880  0.066926  0.013555   -0.030227
# 27                         0.081571 -0.006659 -0.015914    0.111169
# 28                         0.092091  0.032387  0.067251   -0.017992
# 29                         0.133685  0.022692  0.058993    0.066500
# 30                         0.147287  0.043712  0.032344    0.063019
# 31                         0.040880  0.029545  0.001981   -0.018831
# 32                         0.081571  0.001552 -0.000525    0.063339
# 33                         0.092091  0.017184  0.065554    0.002385
# 34                         0.133685  0.048573 -0.019993    0.058641
# 35                         0.147287  0.038417  0.093329   -0.014374
# 36                         0.040880  0.027705  0.042688    0.061160
# 37                         0.081571  0.030843  0.037771   -0.035292
# 38                         0.092091 -0.022738  0.031708    0.062340
# 39                         0.133685  0.007194 -0.050745    0.021340
# 40                         0.147287  0.091476 -0.031864    0.021625
# 41                         0.040880  0.022053 -0.018173    0.021991
# 42                         0.081571  0.046727 -0.008386    0.069760
# 43                         0.092091  0.068610  0.026066    0.050851
# 44                         0.133685 -0.054877  0.101845   -0.013002
# 45                         0.147287 -0.004075  0.017095   -0.006154
# 46                         0.040880  0.014106  0.005657    0.005509
# 47                         0.081571  0.016461  0.018593    0.062717
# 48                         0.092091  0.098851  0.022615    0.016035
# 49                         0.133685  0.139790  0.011582   -0.035089
#
#     KMERlimma  KMERclr_pca_regress_out_scale_first10  \
# 0    0.005231                               0.009009
# 1    0.057938                               0.017167
# 2    0.064312                               0.046423
# 3   -0.001831                               0.094362
# 4    0.025354                               0.007712
# 5   -0.026358                              -0.006320
# 6    0.047062                              -0.013953
# 7    0.001669                              -0.008721
# 8   -0.006039                              -0.016749
# 9    0.038264                               0.058927
# 10   0.035744                               0.089029
# 11   0.100867                               0.049844
# 12   0.089306                              -0.046985
# 13   0.030223                              -0.006143
# 14   0.003252                               0.091301
# 15   0.061808                               0.023901
# 16   0.078093                               0.015246
# 17   0.014466                              -0.007974
# 18   0.039732                               0.019363
# 19   0.037929                               0.070843
# 20   0.037619                               0.008048
# 21  -0.011531                               0.051525
# 22  -0.033105                              -0.038271
# 23  -0.003189                               0.030635
# 24   0.068456                               0.043690
# 25   0.093463                               0.012510
# 26   0.018645                              -0.007243
# 27   0.017963                              -0.037624
# 28   0.046135                              -0.010230
# 29   0.022822                               0.011748
# 30   0.019081                               0.086375
# 8         0.040593
# 9         0.025922
# 10       -0.013998
# 11       -0.007127
# 12        0.048408
# 13       -0.042198
# 14        0.037350
# 15       -0.052204
# 16       -0.005170
# 17       -0.032808
# 18        0.071512
# 19        0.036317
# 20        0.070563
# 21       -0.013062
# 22        0.011600
# 23        0.040156
# 24        0.030121
# 25        0.016679
# 26       -0.007586
# 27        0.041179
# 28        0.030126
# 29       -0.006134
# 30       -0.062790
# 31        0.024673
# 32        0.026809
# 33       -0.015723
# 34       -0.012950
# 35        0.032532
# 36       -0.051948
# 37       -0.005496
# 38        0.021840
# 39        0.052427
# 40        0.036638
# 41        0.049398
# 42       -0.010092
# 43        0.060682
# 44       -0.015104
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49             NaN

# %%
select_columns_bool = True

# %%
# ['6-mers norm', '6-mers no_scale_clr','6-mers scale_clr','7-mers norm','7-mers no_scale_clr','7-mers scale_clr']
# ['6-mers Raw', '6-mers MINVERVA','6-mers MINERVA-scale', '7-mers Raw','7-mers MINVERVA','7-mers MINVERVA-scale']
# Make boxplot for one group only

current_palette = sns.color_palette()
#sns.palplot(current_palette)
palette = sns.color_palette("hls", 8)
plot_color = palette.as_hex()

select_columns = ['OTUraw','OTUbmc','OTUComBat','OTUlimma',
                                 'KMERraw',"KMERComBat","KMERsmartsva","KMERno_scale_clr"]

# ['OTUraw','OTUbmc','OTUComBat','OTUlimma',
#                                  'OTUclr_pca_regress_out_no_scale',"KMERnorm","KMERno_scale_clr"]

select_labels = ['OTU raw','OTU BMC','OTU ComBat','OTU limma',
                                     "K-mer raw","K-mer ComBat","K-mer smartsva*","K-mer MINERVA"]
#['OTU raw','OTU BMC','OTU ComBat','OTU limma',"OTU MINERVA","K-mer raw", "K-mer MINERVA"]


# ['OTU raw','OTU BMC','OTU ComBat','OTU limma',
#                                      "K-mer raw","K-mer ComBat","K-mer smartsva*",
#                                     "K-mer MINERVA"]
if select_columns_bool:
    g=sns.boxplot( data = df_metric[select_columns],palette=plot_color)
    #plot_color[0:4] + [plot_color[7]] + [plot_color[4]] + [plot_color[7]
    g.set_xticklabels(rotation=90,labels = select_labels) #df_metric.columns
else:
    g=sns.boxplot( data = df_metric)
    g.set_xticklabels(rotation=90,labels = df_metric.columns)
    
g.set_title(title)
#plt.savefig(plot_folder + 'boxplots_' + classifier + '_' + metric_word + '.pdf',bbox_inches='tight')
#plt.savefig(plot_folder + 'boxplots_' + classifier + '_' + metric_word +'.png',bbox_inches='tight')
# Out:
# Text(0.5,1,'AUC for prediction of antibiotic history')

# %%
# Out:
# ['#db5f57', '#dbc257', '#91db57', '#db57b2', '#57d3db', '#db57b2']

# %%
plot_color
# Out:
# ['#db5f57', '#dbd057', '#75db57', '#57dbaa', '#579bdb', '#8557db', '#db57c0']
