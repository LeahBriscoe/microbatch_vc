# %%
args =  ["classifier.py","/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc", "CRC_k6&CRC_k7", "kmer",\
         "BatchCorrected",  "bin_crc_normal",1,0,1,1]

# %%
import sys
import pandas as pd
import utils
import numpy as np
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection 
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, cross_val_score
import statsmodels.formula.api as sm
from sklearn.metrics import roc_auc_score
from collections import Counter
from timeit import default_timer as timer

# %%
greater_folder = args[1] # what folder do you save your different datasets in
study_names = args[2].split("&")  # what is the name of the dataset (tells the program which folder to check)
data_type = args[3] # type of data. kmer vs OTU

prefix_name = args[4] # what is the prefix of the file name
column_of_interest = args[5] # what is the phenotype you are predicting (use the same name in the column of the metadata you want to predict), this programs reads from metadata.txt

norm_input = bool(int(args[6]))
map_with_accession = bool(int(args[7]))

if len(args) > 5:
    label_pos_or_neg = int(args[8]) # do you want to treat CRC as positive class or negative class? 
    target_label = args[9] # phenotype representing positive class or negative class? eg. CRC eg. H
    print(target_label)
else:
    label_pos_or_neg = 1
    target_label = 1
use_domain_pheno = False # for when running raw to compare to domain pheno
data_folders = [greater_folder + "/data/" + study_name + "/" for study_name in study_names]   

num_pcs = 20

rf_params = ['criterion','max_features','min_samples_leaf', 'n_estimators']
# Out:
# 1

# %%
#########################################################################
###### COMMENTARY: load data from your k-mer matrix, load metadata ######
#########################################################################

feature_table_dict = utils.load_feature_table(data_folders,data_type = data_type)
metadata = pd.read_csv(data_folders[0] + "metadata.txt",delimiter="\t")

if norm_input:
    for d in range(len(study_names)):
        #feature_table_dict[d] = normalize(np.array(feature_table_dict[d].transpose()), axis = 1, norm = 'l1')
        temp = pd.DataFrame(normalize(feature_table_dict[d].transpose(), axis = 1, norm = 'l1').transpose())
        temp.index = feature_table_dict[d].index
        temp.columns = feature_table_dict[d].columns
        feature_table_dict[d] = temp

# %%
if "AGP" in study_names[0]:
    for d in range(len(study_names)):
        tissue_samples = metadata.index[metadata['body_habitat.x'] == "UBERON:feces"]

        feature_table_dict[d] = feature_table_dict[d][tissue_samples]
        metadata = metadata.loc[tissue_samples]

# %%
labels = metadata[column_of_interest]

# %%
def pca_regression(y,X):
    model = sm.OLS(y,X)
    results = model.fit()
    predictedValues = results.predict()
    residuals = y - predictedValues
    return(residuals)

def RF_grid_search(data,labels,param_dict):
    rf = RandomForestClassifier()
    clf = GridSearchCV(rf, param_dict,scoring="roc_auc")
    clf.fit(data, labels)

    print("Best parameters set found on development set:")
    best_params = clf.best_params_
    return clf,best_params

def RF_cv(data,labels,param_dict):
    clf = RandomForestClassifier(max_depth=5, random_state=0,n_estimators = param_dict['n_estimators'],\
            criterion = param_dict['criterion'],min_samples_leaf = param_dict['min_samples_leaf'],\
                           max_features = param_dict['max_features'])
    results = cross_val_score(clf,X=data,y=labels,scoring="roc_auc")
    return(results)

# %%
# outline
# for data_table:
    # test train split
    # for train
    # for PC number:
        # regress out PCs
        # for grid cell:
            # get accuracy:
        # get max accuracy
    # get max accuracy across PCs
    # for test
    # get the test accuracy with best parameters
    # save best grid and best PCs

# %%
# get PC scores
pc_table_dict = dict()
feature_table_np = dict()
labels_np = dict()
pca = PCA(n_components=num_pcs,svd_solver='randomized')
for d in range(len(study_names)):
    temp = feature_table_dict[d].transpose()
    pca.fit(temp)
    pc_table_dict[d] = pca.transform(temp)
    
    feature_table_np[d] = np.array(feature_table_dict[0])
    labels_np[d] = np.array(labels)

# %%
n_splits = 5
n_repeats = 1
rskf = model_selection.RepeatedStratifiedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=123)
parameter_dict = {'n_estimators':[1000],'criterion': ['entropy'],'min_samples_leaf': [15],\
                 'max_features':[0.3]}

# %%
# Regress out PCs
all_datasets_dict =  dict()
# For each dataset (kmer size)

start = timer()


for d in range(len(study_names)): # range(1):#
    dataset_start= timer()
    
    results_dict = dict()
    
    X = feature_table_np[d].transpose()
    y = labels_np[d]
    pc_scores = pc_table_dict[d] # get pc scores
    na_mask = pd.isna(y)
    
    X = X[~na_mask,:]
    y = y[~na_mask]
    pc_scores = pc_scores[~na_mask,:]
    # for each test train split in 5 fold cross validation
    
    train_it = 0
    for train_index, test_index in rskf.split(X, y):
        
        test_train_start = timer()
        #print(train_index)
        #print(test_index)
        
        X_train, X_test = X[train_index,], X[test_index,]
        y_train, y_test = y[train_index], y[test_index]
        pc_scores_train, pc_scores_test =  pc_scores[train_index], pc_scores[test_index]
        
        if train_it == 0: 
            results_dict["number samples"] = []
        results_dict["number samples"].append(X_train.shape[0])
        # for each PC we regress out 
        for p in range(num_pcs): #range(3):#
            if train_it == 0: 
                results_dict["PC" + str(p)] = dict()
                results_dict["PC" + str(p)]['train_best_params'] = dict()
                results_dict["PC" + str(p)]['train_auc_trained'] = []
                results_dict["PC" + str(p)]['mean_train_cv_auc'] = []
                results_dict["PC" + str(p)]['mean_test_cv_auc'] = []
                results_dict["PC" + str(p)]['test_auc_trained'] = []
               
            if p == 0:
                X_train_corrected = X_train
                X_test_corrected = X_test
            else:
                X_train_corrected = pca_regression(X_train,pc_scores_train[:,0:p])
                X_test_corrected = pca_regression(X_test,pc_scores_test[:,0:p])
            
            # perform grid search on train
            best_train_model, best_params = RF_grid_search(X_train_corrected, y_train,parameter_dict)
            print("finished grid search: " + "train it " + str(train_it) + ", PC" + str(p))
            y_train_pred_prob = best_train_model.predict_proba(X_train_corrected)
            results_dict["PC" + str(p)]['train_best_params'][train_it] = best_params
            already_trained_auc = roc_auc_score(y_true = y_train, y_score = y_train_pred_prob[:,1])
            results_dict["PC" + str(p)]['train_auc_trained'].append(already_trained_auc)
            print("already train Rf " + str(already_trained_auc))
            
            newly_trained_auc = RF_cv(X_train_corrected,y_train,best_params)
            
            results_dict["PC" + str(p)]['mean_train_cv_auc'].append(np.mean(newly_trained_auc))
            print("mean train Rf " + str(np.mean(newly_trained_auc)))
            
            
            
            # perform cv result on test with best param
            test_RF = RF_cv(X_test_corrected,y_test,best_params)
            results_dict["PC" + str(p)]['mean_test_cv_auc'].append(np.mean(test_RF))
            print("mean test Rf " + str(np.mean(test_RF)))
            
            y_test_pred_prob = best_train_model.predict_proba(X_test_corrected)
            already_trained_test_auc = roc_auc_score(y_true = y_test, y_score = y_test_pred_prob[:,1])
            
            print("already train model test RF" + str(already_trained_test_auc))
            results_dict["PC" + str(p)]['test_auc_trained'].append(already_trained_test_auc)
            
            
        train_it += 1
        test_train_end = timer()
        print("Finished one test train split")
        print(test_train_end - test_train_start)

    all_datasets_dict["dataset" + str(d)] = results_dict
    
    dataset_end = timer()
    print("Finished one dataset")
    print(dataset_end - dataset_start)

# ...
end = timer()
print(end - start)
# Out:
# Best parameters set found on development set:
# finished grid search: train it 0, PC0
# already train Rf 0.9972662982112082
# mean train Rf 0.6330473163119987
# mean test Rf 0.7111314611314611
# already train model test RF0.830787037037037
# Best parameters set found on development set:
# finished grid search: train it 0, PC1
# already train Rf 0.9976525821596244
# mean train Rf 0.6337508602656091
# mean test Rf 0.6550671550671551
# already train model test RF0.7886574074074073
# Best parameters set found on development set:
# finished grid search: train it 0, PC2
# already train Rf 0.9972365840613301
# mean train Rf 0.6301650006473286
# mean test Rf 0.6235246235246236
# already train model test RF0.7280092592592593
# Best parameters set found on development set:
# finished grid search: train it 0, PC3
# already train Rf 0.9939977417246093
# mean train Rf 0.6278124723181858
# mean test Rf 0.5802808302808303
# already train model test RF0.655787037037037
# Best parameters set found on development set:
# finished grid search: train it 0, PC4
# already train Rf 0.9964343020146194
# mean train Rf 0.6273269758853071
# mean test Rf 0.5964590964590966
# already train model test RF0.7002314814814815
# Best parameters set found on development set:
# finished grid search: train it 0, PC5
# already train Rf 0.9969691567124264
# mean train Rf 0.6227667164087572
# mean test Rf 0.6678876678876678
# already train model test RF0.7011574074074075
# Best parameters set found on development set:
# finished grid search: train it 0, PC6
# already train Rf 0.9968800142627919
# mean train Rf 0.6260680921523335
# mean test Rf 0.7132682132682132
# already train model test RF0.6400462962962964
# Best parameters set found on development set:
# finished grid search: train it 0, PC7
# already train Rf 0.99723658406133
# mean train Rf 0.6242180952186268
# mean test Rf 0.7339234839234839
# already train model test RF0.6395833333333334
# Best parameters set found on development set:
# finished grid search: train it 0, PC8
# already train Rf 0.9971474416116954
# mean train Rf 0.6192166302118468
# mean test Rf 0.7200854700854701
# already train model test RF0.5766203703703703
# Best parameters set found on development set:
# finished grid search: train it 0, PC9
# already train Rf 0.9958697331669341
# mean train Rf 0.6297578650422127
# mean test Rf 0.6925111925111925
# already train model test RF0.568287037037037
# Best parameters set found on development set:
# finished grid search: train it 0, PC10
# already train Rf 0.9968205859630356
# mean train Rf 0.6107996552123578
# mean test Rf 0.6740944240944241
# already train model test RF0.5793981481481482
# Best parameters set found on development set:
# finished grid search: train it 0, PC11
# already train Rf 0.9953943067688833
# mean train Rf 0.572017859454745
# mean test Rf 0.6464183964183965
# already train model test RF0.6122685185185186
# Best parameters set found on development set:
# finished grid search: train it 0, PC12
# already train Rf 0.9949485945207108
# mean train Rf 0.5792168346313975
# mean test Rf 0.6206756206756207
# already train model test RF0.5817129629629629
# Best parameters set found on development set:
# finished grid search: train it 0, PC13
# already train Rf 0.9964045878647412
# mean train Rf 0.5825079893974393
# mean test Rf 0.58994708994709
# already train model test RF0.5872685185185186
# Best parameters set found on development set:
# finished grid search: train it 0, PC14
# already train Rf 0.9963154454151066
# mean train Rf 0.5893458233678802
# mean test Rf 0.5759055759055759
# already train model test RF0.6358796296296297
# Best parameters set found on development set:
# finished grid search: train it 0, PC15
# already train Rf 0.9961965888155939
# mean train Rf 0.5859882322478654
# mean test Rf 0.5674603174603176
# already train model test RF0.6354166666666667
# Best parameters set found on development set:
# finished grid search: train it 0, PC16
# already train Rf 0.9952457360194924
# mean train Rf 0.5952961357890936
# mean test Rf 0.5955433455433456
# already train model test RF0.6131944444444445
# Best parameters set found on development set:
# finished grid search: train it 0, PC17
# already train Rf 0.9954834492185178
# mean train Rf 0.6140294841131939
# mean test Rf 0.6106023606023606
# already train model test RF0.5974537037037038
# Best parameters set found on development set:
# finished grid search: train it 0, PC18
# already train Rf 0.9945028822725381
# mean train Rf 0.60697019562951
# mean test Rf 0.620980870980871
# already train model test RF0.6164351851851851
# Best parameters set found on development set:
# finished grid search: train it 0, PC19
# already train Rf 0.994294883223391
# mean train Rf 0.6211177320332251
# mean test Rf 0.5878103378103379
# already train model test RF0.6497685185185185
# Finished one test train split
# 4947.710449150007
# Best parameters set found on development set:
# finished grid search: train it 1, PC0
# already train Rf 0.9967017293635229
# mean train Rf 0.6443772699087607
# mean test Rf 0.5541310541310541
# already train model test RF0.8527777777777779
# Best parameters set found on development set:
# finished grid search: train it 1, PC1
# already train Rf 0.9962263029654722
# mean train Rf 0.6195402945004327
# mean test Rf 0.49664224664224665
# already train model test RF0.8296296296296296
# Best parameters set found on development set:
# finished grid search: train it 1, PC2
# already train Rf 0.9973257265109645
# mean train Rf 0.5999943784623561
# mean test Rf 0.47517297517297524
# already train model test RF0.8365740740740741
# Best parameters set found on development set:
# finished grid search: train it 1, PC3
# already train Rf 0.9955428775182742
# mean train Rf 0.5862437566862228
# mean test Rf 0.37515262515262515
# already train model test RF0.7555555555555555
# Best parameters set found on development set:
# finished grid search: train it 1, PC4
# already train Rf 0.9953943067688833
# mean train Rf 0.5931906144170295
# mean test Rf 0.4026251526251527
# already train model test RF0.7685185185185186
# Best parameters set found on development set:
# finished grid search: train it 1, PC5
# already train Rf 0.9970880133119392
# mean train Rf 0.5958821385010596
# mean test Rf 0.45594220594220597
# already train model test RF0.7333333333333334
# Best parameters set found on development set:
# finished grid search: train it 1, PC6
# already train Rf 0.9963451595649848
# mean train Rf 0.5841331248253917
# mean test Rf 0.47018722018722015
# already train model test RF0.736111111111111
# Best parameters set found on development set:
# finished grid search: train it 1, PC7
# already train Rf 0.9959588756165686
# mean train Rf 0.5987371982256383
# mean test Rf 0.4746642246642246
# already train model test RF0.7277777777777777
# Best parameters set found on development set:
# finished grid search: train it 1, PC8
# already train Rf 0.9973257265109645
# mean train Rf 0.5832200508323283
# mean test Rf 0.36579161579161584
# already train model test RF0.6847222222222222
# Best parameters set found on development set:
# finished grid search: train it 1, PC9
# already train Rf 0.9964937303143757
# mean train Rf 0.602561547319719
# mean test Rf 0.3781033781033781
# already train model test RF0.6981481481481482
# Best parameters set found on development set:
# finished grid search: train it 1, PC10
# already train Rf 0.9963154454151067
# mean train Rf 0.5896592666789319
# mean test Rf 0.3766788766788767
# already train model test RF0.6972222222222222
# Best parameters set found on development set:
# finished grid search: train it 1, PC11
# already train Rf 0.995334878469127
# mean train Rf 0.6091728162881499
# mean test Rf 0.389092389092389
# already train model test RF0.6606481481481481
# Best parameters set found on development set:
# finished grid search: train it 1, PC12
# already train Rf 0.9946811671718072
# mean train Rf 0.5946079233017846
# mean test Rf 0.42246642246642246
# already train model test RF0.5944444444444444
# Best parameters set found on development set:
# finished grid search: train it 1, PC13
# already train Rf 0.9969394425625483
# mean train Rf 0.595335316202975
# mean test Rf 0.5598290598290597
# already train model test RF0.5393518518518519
# Best parameters set found on development set:
# finished grid search: train it 1, PC14
# already train Rf 0.9969394425625483
# mean train Rf 0.6050299133942504
# mean test Rf 0.5805860805860806
# already train model test RF0.513425925925926
# Best parameters set found on development set:
# finished grid search: train it 1, PC15
# already train Rf 0.9975337255601118
# mean train Rf 0.5960405636528411
# mean test Rf 0.5627798127798128
# already train model test RF0.5361111111111111
# Best parameters set found on development set:
# finished grid search: train it 1, PC16
# already train Rf 0.99723658406133
# mean train Rf 0.5923184243341033
# mean test Rf 0.5299145299145298
# already train model test RF0.5388888888888889
# Best parameters set found on development set:
# finished grid search: train it 1, PC17
# already train Rf 0.9975040114102336
# mean train Rf 0.5962126167746683
# mean test Rf 0.5140415140415141
# already train model test RF0.5074074074074074
# Best parameters set found on development set:
# finished grid search: train it 1, PC18
# already train Rf 0.9966125869138884
# mean train Rf 0.5815540314942388
# mean test Rf 0.5655270655270656
# already train model test RF0.5125000000000001
# Best parameters set found on development set:
# finished grid search: train it 1, PC19
# already train Rf 0.996880014262792
# mean train Rf 0.5801622750533194
# mean test Rf 0.5963573463573463
# already train model test RF0.5
# Finished one test train split
# 4855.238079595001
# Best parameters set found on development set:
# finished grid search: train it 2, PC0
# already train Rf 0.9966875665444221
# mean train Rf 0.6713781587552515
# mean test Rf 0.35061888003064473
# already train model test RF0.7731132075471698
# Best parameters set found on development set:
# finished grid search: train it 2, PC1
# already train Rf 0.9963918135573169
# mean train Rf 0.6601228750776983
# mean test Rf 0.37805549570255453
# already train model test RF0.7433962264150944
# Best parameters set found on development set:
# finished grid search: train it 2, PC2
# already train Rf 0.9982254820773689
# mean train Rf 0.6336668211169939
# mean test Rf 0.40837104072398195
# already train model test RF0.7410377358490565
# Best parameters set found on development set:
# finished grid search: train it 2, PC3
# already train Rf 0.9950313498166331
# mean train Rf 0.6137988496479063
# mean test Rf 0.4365019512078336
# already train model test RF0.7018867924528301
# Best parameters set found on development set:
# finished grid search: train it 2, PC4
# already train Rf 0.9960664852715013
# mean train Rf 0.6145998714428159
# mean test Rf 0.4559003088414853
# already train model test RF0.6830188679245284
# Best parameters set found on development set:
# finished grid search: train it 2, PC5
# already train Rf 0.9958003075831066
# mean train Rf 0.6154062876425352
# mean test Rf 0.4111362493715435
# already train model test RF0.6806603773584905
# Best parameters set found on development set:
# finished grid search: train it 2, PC6
# already train Rf 0.9960369099727907
# mean train Rf 0.5854045955029212
# mean test Rf 0.4818405994876584
# already train model test RF0.6919811320754717
# Best parameters set found on development set:
# finished grid search: train it 2, PC7
# already train Rf 0.9954749792972909
# mean train Rf 0.587308347207364
# mean test Rf 0.46372309607603723
# already train model test RF0.6943396226415095
# Best parameters set found on development set:
# finished grid search: train it 2, PC8
# already train Rf 0.996805867739264
# mean train Rf 0.5642282442707636
# mean test Rf 0.5555136584548349
# already train model test RF0.739622641509434
# Best parameters set found on development set:
# finished grid search: train it 2, PC9
# already train Rf 0.9970720454276588
# mean train Rf 0.5671630844033183
# mean test Rf 0.556650865474395
# already train model test RF0.7367924528301887
# Best parameters set found on development set:
# finished grid search: train it 2, PC10
# already train Rf 0.997249497219922
# mean train Rf 0.5552211024573501
# mean test Rf 0.5991883933060403
# already train model test RF0.6764150943396227
# Best parameters set found on development set:
# finished grid search: train it 2, PC11
# already train Rf 0.9965396900508695
# mean train Rf 0.5575785519978983
# mean test Rf 0.5331465919701214
# already train model test RF0.5971698113207548
# Best parameters set found on development set:
# finished grid search: train it 2, PC12
# already train Rf 0.9963918135573169
# mean train Rf 0.5716153611449918
# mean test Rf 0.5505877564701094
# already train model test RF0.595754716981132
# Best parameters set found on development set:
# finished grid search: train it 2, PC13
# already train Rf 0.9974565243108955
# mean train Rf 0.5587116609239916
# mean test Rf 0.5493966817496229
# already train model test RF0.5938679245283018
# Best parameters set found on development set:
# finished grid search: train it 2, PC14
# already train Rf 0.9961847864663433
# mean train Rf 0.5784803564168431
# mean test Rf 0.584279010749599
# already train model test RF0.5306603773584906
# Best parameters set found on development set:
# finished grid search: train it 2, PC15
# already train Rf 0.9973973737134745
# mean train Rf 0.6084491142955134
# mean test Rf 0.5563516004692476
# already train model test RF0.5745283018867925
# Best parameters set found on development set:
# finished grid search: train it 2, PC16
# already train Rf 0.9973677984147641
# mean train Rf 0.5948284314282188
# mean test Rf 0.6123859800330389
# already train model test RF0.5528301886792453
# Best parameters set found on development set:
# finished grid search: train it 2, PC17
# already train Rf 0.996628415947001
# mean train Rf 0.594302713555969
# mean test Rf 0.6073463573463573
# already train model test RF0.5259433962264151
# Best parameters set found on development set:
# finished grid search: train it 2, PC18
# already train Rf 0.9972199219212114
# mean train Rf 0.5988143287505499
# mean test Rf 0.5604575163398693
# already train model test RF0.5273584905660377
# Best parameters set found on development set:
# finished grid search: train it 2, PC19
# already train Rf 0.9960073346740803
# mean train Rf 0.6006274165987162
# mean test Rf 0.6109495080083315
# already train model test RF0.5132075471698113
# Finished one test train split
# 5155.086476539
# Best parameters set found on development set:
# finished grid search: train it 3, PC0
# already train Rf 0.9947099277023452
# mean train Rf 0.6651423214338442
# mean test Rf 0.5628456510809452
# already train model test RF0.6722302854378327
# Best parameters set found on development set:
# finished grid search: train it 3, PC1
# already train Rf 0.9955328278375359
# mean train Rf 0.6379637011446738
# mean test Rf 0.5755823697000167
# already train model test RF0.6654571843251088
# Best parameters set found on development set:
# finished grid search: train it 3, PC2
# already train Rf 0.9966790101686945
# mean train Rf 0.6150468499325795
# mean test Rf 0.5635160046924752
# already train model test RF0.6635220125786163
# Best parameters set found on development set:
# finished grid search: train it 3, PC3
# already train Rf 0.9961206136483866
# mean train Rf 0.6148918317733093
# mean test Rf 0.481649069884364
# already train model test RF0.6325592646347362
# Best parameters set found on development set:
# finished grid search: train it 3, PC4
# already train Rf 0.9963851172632693
# mean train Rf 0.6011259731695554
# mean test Rf 0.5072063013239484
# already train model test RF0.576923076923077
# Best parameters set found on development set:
# finished grid search: train it 3, PC5
# already train Rf 0.9958267207429612
# mean train Rf 0.6214788732394366
# mean test Rf 0.5162560750796046
# already train model test RF0.5972423802612481
# Best parameters set found on development set:
# finished grid search: train it 3, PC6
# already train Rf 0.9954740492564509
# mean train Rf 0.6557378864381256
# mean test Rf 0.48273839450310035
# already train model test RF0.627721335268505
# Best parameters set found on development set:
# finished grid search: train it 3, PC7
# already train Rf 0.9971198495268325
# mean train Rf 0.6452126455448274
# mean test Rf 0.4897771074241663
# already train model test RF0.616594097726173
# Best parameters set found on development set:
# finished grid search: train it 3, PC8
# already train Rf 0.996590842297067
# mean train Rf 0.6128347654058522
# mean test Rf 0.5001675884028826
# already train model test RF0.6238509917755201
# Best parameters set found on development set:
# finished grid search: train it 3, PC9
# already train Rf 0.9963851172632693
# mean train Rf 0.6188005039320479
# mean test Rf 0.5579017931959109
# already train model test RF0.611756168359942
# Best parameters set found on development set:
# finished grid search: train it 3, PC10
# already train Rf 0.9957679421618763
# mean train Rf 0.6305400537396285
# mean test Rf 0.48541980894922077
# already train model test RF0.6093372036768263
# Best parameters set found on development set:
# finished grid search: train it 3, PC11
# already train Rf 0.9957385528713336
# mean train Rf 0.6259596362240528
# mean test Rf 0.38796715267303505
# already train model test RF0.5938558297048864
# Best parameters set found on development set:
# finished grid search: train it 3, PC12
# already train Rf 0.9946217598307178
# mean train Rf 0.6119071170559345
# mean test Rf 0.4119322942852355
# already train model test RF0.5977261731978714
# Best parameters set found on development set:
# finished grid search: train it 3, PC13
# already train Rf 0.9958561100335038
# mean train Rf 0.6491151661893091
# mean test Rf 0.48014077425842133
# already train model test RF0.5870827285921626
# Best parameters set found on development set:
# finished grid search: train it 3, PC14
# already train Rf 0.9938282489860695
# mean train Rf 0.6513272507160363
# mean test Rf 0.5021786492374728
# already train model test RF0.5846637639090468
# Best parameters set found on development set:
# finished grid search: train it 3, PC15
# already train Rf 0.9935931346617293
# mean train Rf 0.6486242753516206
# mean test Rf 0.4482151835093012
# already train model test RF0.6253023705853895
# Best parameters set found on development set:
# finished grid search: train it 3, PC16
# already train Rf 0.992740845235996
# mean train Rf 0.6214727217251799
# mean test Rf 0.4480475951064187
# already train model test RF0.6127237542331883
# Best parameters set found on development set:
# finished grid search: train it 3, PC17
# already train Rf 0.9932404631752189
# mean train Rf 0.6230548911920158
# mean test Rf 0.45542148483324957
# already train model test RF0.5928882438316401
# Best parameters set found on development set:
# finished grid search: train it 3, PC18
# already train Rf 0.9917122200670077
# mean train Rf 0.6150234741784038
# mean test Rf 0.4444444444444445
# already train model test RF0.588534107402032
# Best parameters set found on development set:
# finished grid search: train it 3, PC19
# already train Rf 0.9933286310468464
# mean train Rf 0.6141499591539453
# mean test Rf 0.44226579520697173
# already train model test RF0.60062893081761
# Finished one test train split
# 5802.830563631025
# Best parameters set found on development set:
# finished grid search: train it 4, PC0
# already train Rf 0.9986187033445013
# mean train Rf 0.6930628143423786
# mean test Rf 0.5068711245181833
# already train model test RF0.7692307692307693
# Best parameters set found on development set:
# finished grid search: train it 4, PC1
# already train Rf 0.9992946570269794
# mean train Rf 0.6584236375626225
# mean test Rf 0.451064186358304
# already train model test RF0.7663280116110305
# Best parameters set found on development set:
# finished grid search: train it 4, PC2
# already train Rf 0.9992064891553518
# mean train Rf 0.6598729343215126
# mean test Rf 0.4027149321266969
# already train model test RF0.7556845670053217
# Best parameters set found on development set:
# finished grid search: train it 4, PC3
# already train Rf 0.997825192499853
# mean train Rf 0.6028877668526885
# mean test Rf 0.4647226411932295
# already train model test RF0.7745524915336237
# Best parameters set found on development set:
# finished grid search: train it 4, PC4
# already train Rf 0.998324810439076
# mean train Rf 0.6214247399139773
# mean test Rf 0.4780459192223898
# already train model test RF0.737300435413643
# Best parameters set found on development set:
# finished grid search: train it 4, PC5
# already train Rf 0.9987068712161289
# mean train Rf 0.6064408814873868
# mean test Rf 0.47150997150997154
# already train model test RF0.7150459603289792
# Best parameters set found on development set:
# finished grid search: train it 4, PC6
# already train Rf 0.9986187033445013
# mean train Rf 0.6125025836359879
# mean test Rf 0.378917378917379
# already train model test RF0.7034349298500242
# Best parameters set found on development set:
# finished grid search: train it 4, PC7
# already train Rf 0.998883206959384
# mean train Rf 0.6229786124152321
# mean test Rf 0.4127702362996481
# already train model test RF0.6298984034833092
# Best parameters set found on development set:
# finished grid search: train it 4, PC8
# already train Rf 0.9985011461823311
# mean train Rf 0.6045794332732944
# mean test Rf 0.39576001340707223
# already train model test RF0.6347363328495403
# Best parameters set found on development set:
# finished grid search: train it 4, PC9
# already train Rf 0.9985011461823311
# mean train Rf 0.6167840375586855
# mean test Rf 0.3838612368024133
# already train model test RF0.6357039187227866
# Best parameters set found on development set:
# finished grid search: train it 4, PC10
# already train Rf 0.9982366425674484
# mean train Rf 0.6094563537760455
# mean test Rf 0.3822691469750293
# already train model test RF0.6545718432510885
# Best parameters set found on development set:
# finished grid search: train it 4, PC11
# already train Rf 0.9971786281079175
# mean train Rf 0.5828129152272123
# mean test Rf 0.595944360650243
# already train model test RF0.5732946298984034
# Best parameters set found on development set:
# finished grid search: train it 4, PC12
# already train Rf 0.9970022923646623
# mean train Rf 0.5890628537120698
# mean test Rf 0.6137925255572315
# already train model test RF0.5578132559264635
# Best parameters set found on development set:
# finished grid search: train it 4, PC13
# already train Rf 0.9974725210133427
# mean train Rf 0.5770550978828948
# mean test Rf 0.6137087313557902
# already train model test RF0.5200774068698597
# Best parameters set found on development set:
# finished grid search: train it 4, PC14
# already train Rf 0.997825192499853
# mean train Rf 0.5909538291945945
# mean test Rf 0.6090162560750796
# already train model test RF0.5486211901306242
# Best parameters set found on development set:
# finished grid search: train it 4, PC15
# already train Rf 0.9981190854052784
# mean train Rf 0.6257787817049044
# mean test Rf 0.5832076420311715
# already train model test RF0.5781325592646348
# Best parameters set found on development set:
# finished grid search: train it 4, PC16
# already train Rf 0.9982954211485335
# mean train Rf 0.620119388588695
# mean test Rf 0.5080442433383611
# already train model test RF0.5761973875181423
# Best parameters set found on development set:
# finished grid search: train it 4, PC17
# already train Rf 0.9979427496620232
# mean train Rf 0.6112845838131515
# mean test Rf 0.5051952404893582
# already train model test RF0.5650701499758103
# Best parameters set found on development set:
# finished grid search: train it 4, PC18
# already train Rf 0.9979721389525656
# mean train Rf 0.6010743004497988
# mean test Rf 0.5579855873973522
# already train model test RF0.5447508466376391
# Best parameters set found on development set:
# finished grid search: train it 4, PC19
# already train Rf 0.9978251924998531
# mean train Rf 0.605379130126672
# mean test Rf 0.47092341209988264
# already train model test RF0.5655539429124334
# Finished one test train split
# 4712.786725865997
# Finished one dataset
# 25473.701319393003
# Best parameters set found on development set:
# finished grid search: train it 0, PC0
# already train Rf 0.9974148689605989
# mean train Rf 0.6330473163119987
# mean test Rf 0.7111314611314611
# already train model test RF0.8349537037037037
# Best parameters set found on development set:
# finished grid search: train it 0, PC1
# already train Rf 0.9974445831104772
# mean train Rf 0.643179712040993
# mean test Rf 0.6566951566951568
# already train model test RF0.7844907407407407
# Best parameters set found on development set:
# finished grid search: train it 0, PC2
# already train Rf 0.9954834492185178
# mean train Rf 0.6343283454962966
# mean test Rf 0.5953398453398454
# already train model test RF0.6886574074074073
# Best parameters set found on development set:
# finished grid search: train it 0, PC3
# already train Rf 0.9948297379211981
# mean train Rf 0.6255212698542489
# mean test Rf 0.5217745217745218
# already train model test RF0.6752314814814815
# Best parameters set found on development set:
# finished grid search: train it 0, PC4
# already train Rf 0.9968205859630357
# mean train Rf 0.6357575788548416
# mean test Rf 0.6138583638583638
# already train model test RF0.7108796296296296
# Best parameters set found on development set:
# finished grid search: train it 0, PC5
# already train Rf 0.9974742972603554
# mean train Rf 0.6275825003236642
# mean test Rf 0.6451973951973953
# already train model test RF0.6831018518518519
# Best parameters set found on development set:
# finished grid search: train it 0, PC6
# already train Rf 0.9970582991620609
# mean train Rf 0.6342005832771179
# mean test Rf 0.7127594627594628
# already train model test RF0.6030092592592592
# Best parameters set found on development set:
# finished grid search: train it 0, PC7
# already train Rf 0.9962263029654721
# mean train Rf 0.623935314840178
# mean test Rf 0.7173382173382173
# already train model test RF0.6164351851851851
# Best parameters set found on development set:
# finished grid search: train it 0, PC8
# already train Rf 0.9971474416116954
# mean train Rf 0.6288226455978251
# mean test Rf 0.7058404558404558
# already train model test RF0.5937500000000001
# Best parameters set found on development set:
# finished grid search: train it 0, PC9
# already train Rf 0.997414868960599
# mean train Rf 0.6451574711938783
# mean test Rf 0.6755189255189255
# already train model test RF0.6025462962962963
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-debab7659608> in <module>
#      52
#      53             # perform grid search on train
# ---> 54             best_train_model, best_params = RF_grid_search(X_train_corrected, y_train,parameter_dict)
#      55             print("finished grid search: " + "train it " + str(train_it) + ", PC" + str(p))
#      56             y_train_pred_prob = best_train_model.predict_proba(X_train_corrected)
#
# <ipython-input-7-cb8d767d7010> in RF_grid_search(data, labels, param_dict)
#       9     rf = RandomForestClassifier()
#      10     clf = GridSearchCV(rf, param_dict,scoring="roc_auc")
# ---> 11     clf.fit(data, labels)
#      12
#      13     print("Best parameters set found on development set:")
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     637                                   error_score=self.error_score)
#     638           for parameters, (train, test) in product(candidate_params,
# --> 639                                                    cv.split(X, y, groups)))
#     640
#     641         # if one choose to see train score, "out" will contain train score info
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, error_score)
#     456             estimator.fit(X_train, **fit_params)
#     457         else:
# --> 458             estimator.fit(X_train, y_train, **fit_params)
#     459
#     460     except Exception as e:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
pickle.dump(all_datasets_dict , open( data_folders[0] +"_MINERVA_tt_grid2.pkl", "wb" ) )

# %%
import pickle
#pickle.dump(all_datasets_dict , open( data_folders[0] +"_MINERVA_tt_grid.pkl", "wb" ) )
#log_all_datasets_dict  = all_datasets_dict    
file = open( data_folders[0] +"_MINERVA_tt_grid.pkl", "rb" )

# dump information to that file
data = pickle.load(file)

# close the file
file.close()

# %%
data['dataset0']["PC" + str(i)]
# Out:
# {'train_best_params': {0: {'criterion': 'entropy',
#    'max_features': 0.3,
#    'min_samples_leaf': 5,
#    'n_estimators': 700},
#   1: {'criterion': 'gini',
#    'max_features': 0.3,
#    'min_samples_leaf': 5,
#    'n_estimators': 500},
#   2: {'criterion': 'gini',
#    'max_features': 0.3,
#    'min_samples_leaf': 5,
#    'n_estimators': 500},
#   3: {'criterion': 'gini',
#    'max_features': 0.3,
#    'min_samples_leaf': 5,
#    'n_estimators': 700},
#   4: {'criterion': 'entropy',
#    'max_features': 0.3,
#    'min_samples_leaf': 5,
#    'n_estimators': 500}},
#  'train_auc': [0.9999108575503655,
#   0.9997325726510965,
#   0.999822548207737,
#   0.9995591606418621,
#   0.999941221418915],
#  'mean_test_cv_auc': [0.703805453805454,
#   0.5790598290598291,
#   0.37934233522468813,
#   0.5952740070387129,
#   0.543154013742249]}

# %%
x = []
y = []
for i in range(20):
    x.append(i)
    y.append(np.mean(data['dataset1']["PC" + str(i)]['train_auc']))

# %%
import matplotlib.pyplot as plt

x = []
y = []
for i in range(20):
    x.append(i)
    y.append(np.mean(data['dataset1']["PC" + str(i)]['train_auc']))
    
plt.plot(x, y)
plt.show()
