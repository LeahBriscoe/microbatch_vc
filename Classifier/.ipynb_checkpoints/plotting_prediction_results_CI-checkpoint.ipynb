# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_folder = '/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/data/'
plot_folder = '/Users/leahbriscoe/Documents/MicroBatch/microbatch_vc/plots/'

# %%
file_names =[ 'otu_BatchCorrected_bmi_corrected_pearson_and_mse',
             'kmer_BatchCorrected_bmi_corrected_pearson_and_mse',
             'kmer_kmer_table_bmi_corrected_pearson_and_mse']



#['bmi_corrected_pearson_and_mse','bmi_corrected_pearson_and_mse']
    
#     file_names =[ 'otu_BatchCorrected_antibiotic_classification_auc',
#              'kmer_BatchCorrected_antibiotic_classification_auc',
#              'kmer_kmer_table_antibiotic_classification_auc'
folder_names = ['AGP_otumatch_otu','AGP_otumatch_k7','AGP_otumatch_k7']#['AGP_healthymax_k6', 'AGP_healthymax_k7']
#['AGP_otumatch_otu','AGP_otumatch_k7','AGP_otumatch_k7']
#['AGP_healthymax_k6', 'AGP_healthymax_k7']
nice_names = ['OTU',"KMER","KMER"]#, 'KMER old batch correct','KMER MINERVA']

metric_word = 'pearson'#'auc_all'
classifier = 'bmi_prediction'#'Naive Bayes'
select_columns_bool = True
title = 'Pearson correlation of predicted body mass index (BMI)'#'AUC for prediction of antibiotic history'

# %%
df_metric = pd.DataFrame()

# %%
for f in range(len(file_names)):

    data_temp = pickle.load( open( data_folder + folder_names[f] +"/"+ file_names[f] + ".pkl" ,"rb"))
    #methods_lists.append([k for k in data1.keys()])   
    for k in data_temp:
        if metric_word == "auc_all":
            df_metric[nice_names[f] + str(k)] = pd.Series(data_temp[k][classifier][metric_word])
        else:
            df_metric[nice_names[f] + str(k)] = pd.Series(data_temp[k][metric_word])

# %%
df_metric
# Out:
#       OTUraw    OTUbmc  OTUComBat  OTUlimma  OTUclr_pca_regress_out_scale  \
# 0   0.069861  0.087074   0.103933  0.087076                      0.101097
# 1   0.028673  0.030624   0.028048  0.030731                      0.153262
# 2   0.071600  0.068041   0.077177  0.067915                      0.002697
# 3   0.079294  0.048391   0.066809  0.048461                      0.089125
# 4   0.095356  0.094011   0.098950  0.093846                      0.088556
# 5   0.069861  0.087074   0.103933  0.087076                      0.101097
# 6   0.028673  0.030624   0.028048  0.030731                      0.153262
# 7   0.071600  0.068041   0.077177  0.067915                      0.002697
# 8   0.079294  0.048391   0.066809  0.048461                      0.089125
# 9   0.095356  0.094011   0.098950  0.093846                      0.088556
# 10  0.069861  0.087074   0.103933  0.087076                      0.101097
# 11  0.028673  0.030624   0.028048  0.030731                      0.153262
# 12  0.071600  0.068041   0.077177  0.067915                      0.002697
# 13  0.079294  0.048391   0.066809  0.048461                      0.089125
# 14  0.095356  0.094011   0.098950  0.093846                      0.088556
# 15  0.069861  0.087074   0.103933  0.087076                      0.101097
# 16  0.028673  0.030624   0.028048  0.030731                      0.153262
# 17  0.071600  0.068041   0.077177  0.067915                      0.002697
# 18  0.079294  0.048391   0.066809  0.048461                      0.089125
# 19  0.095356  0.094011   0.098950  0.093846                      0.088556
# 20  0.069861  0.087074   0.103933  0.087076                      0.101097
# 21  0.028673  0.030624   0.028048  0.030731                      0.153262
# 22  0.071600  0.068041   0.077177  0.067915                      0.002697
# 23  0.079294  0.048391   0.066809  0.048461                      0.089125
# 24  0.095356  0.094011   0.098950  0.093846                      0.088556
# 25  0.069861  0.087074   0.103933  0.087076                      0.101097
# 26  0.028673  0.030624   0.028048  0.030731                      0.153262
# 27  0.071600  0.068041   0.077177  0.067915                      0.002697
# 28  0.079294  0.048391   0.066809  0.048461                      0.089125
# 29  0.095356  0.094011   0.098950  0.093846                      0.088556
# 30  0.069861  0.087074   0.103933  0.087076                      0.101097
# 31  0.028673  0.030624   0.028048  0.030731                      0.153262
# 32  0.071600  0.068041   0.077177  0.067915                      0.002697
# 33  0.079294  0.048391   0.066809  0.048461                      0.089125
# 34  0.095356  0.094011   0.098950  0.093846                      0.088556
#
#     OTUclr_pca_regress_out_no_scale   KMERraw   KMERbmc  KMERComBat  \
# 0                          0.147287  0.046670  0.043965    0.050155
# 1                          0.040880  0.069849  0.071746    0.033174
# 2                          0.081571 -0.023710 -0.022133   -0.019054
# 3                          0.092091  0.024903  0.023857    0.010205
# 4                          0.133685  0.025680  0.028156    0.038394
# 5                          0.147287  0.046670  0.043965    0.050155
# 6                          0.040880  0.069849  0.071746    0.033174
# 7                          0.081571 -0.023710 -0.022133   -0.019054
# 8                          0.092091  0.024903  0.023857    0.010205
# 9                          0.133685  0.025680  0.028156    0.038394
# 10                         0.147287  0.046670  0.043965    0.050155
# 11                         0.040880  0.069849  0.071746    0.033174
# 12                         0.081571 -0.023710 -0.022133   -0.019054
# 13                         0.092091  0.024903  0.023857    0.010205
# 14                         0.133685  0.025680  0.028156    0.038394
# 15                         0.147287  0.046670  0.043965    0.050155
# 16                         0.040880  0.069849  0.071746    0.033174
# 17                         0.081571 -0.023710 -0.022133   -0.019054
# 18                         0.092091  0.024903  0.023857    0.010205
# 19                         0.133685  0.025680  0.028156    0.038394
# 20                         0.147287  0.046670  0.043965    0.050155
# 21                         0.040880  0.069849  0.071746    0.033174
# 22                         0.081571 -0.023710 -0.022133   -0.019054
# 23                         0.092091  0.024903  0.023857    0.010205
# 24                         0.133685  0.025680  0.028156    0.038394
# 25                         0.147287  0.046670  0.043965    0.050155
# 26                         0.040880  0.069849  0.071746    0.033174
# 27                         0.081571 -0.023710 -0.022133   -0.019054
# 28                         0.092091  0.024903  0.023857    0.010205
# 29                         0.133685  0.025680  0.028156    0.038394
# 30                         0.147287  0.046670  0.043965    0.050155
# 31                         0.040880  0.069849  0.071746    0.033174
# 32                         0.081571 -0.023710 -0.022133   -0.019054
# 33                         0.092091  0.024903  0.023857    0.010205
# 34                         0.133685  0.025680  0.028156    0.038394
#
#     KMERlimma  KMERclr_pca_regress_out_scale_first10  \
# 0    0.043797                              -0.009962
# 1    0.071648                               0.022973
# 2   -0.021834                              -0.017461
# 3    0.023913                               0.002120
# 4    0.028247                               0.085198
# 5    0.043797                              -0.009962
# 6    0.071648                               0.022973
# 7   -0.021834                              -0.017461
# 8    0.023913                               0.002120
# 9    0.028247                               0.085198
# 10   0.043797                              -0.009962
# 11   0.071648                               0.022973
# 12  -0.021834                              -0.017461
# 13   0.023913                               0.002120
# 14   0.028247                               0.085198
# 15   0.043797                              -0.009962
# 16   0.071648                               0.022973
# 17  -0.021834                              -0.017461
# 18   0.023913                               0.002120
# 19   0.028247                               0.085198
# 20   0.043797                              -0.009962
# 21   0.071648                               0.022973
# 22  -0.021834                              -0.017461
# 23   0.023913                               0.002120
# 24   0.028247                               0.085198
# 25   0.043797                              -0.009962
# 26   0.071648                               0.022973
# 27  -0.021834                              -0.017461
# 28   0.023913                               0.002120
# 29   0.028247                               0.085198
# 30   0.043797                              -0.009962
# 31   0.071648                               0.022973
# 32  -0.021834                              -0.017461
# 33   0.023913                               0.002120
# 34   0.028247                               0.085198
#
#     KMERclr_pca_regress_out_no_scale_first10  KMERnorm  KMERno_scale_no_clr  \
# 0                                   0.061160  0.046670             0.082388
# 1                                   0.043167  0.069849             0.085810
# 2                                   0.057307 -0.023710             0.012320
# 3                                   0.051506  0.024903             0.021724
# 4                                   0.051214  0.025680             0.052624
# 5                                   0.061160  0.046670             0.082388
# 6                                   0.043167  0.069849             0.085810
# 7                                   0.057307 -0.023710             0.012320
# 8                                   0.051506  0.024903             0.021724
# 9                                   0.051214  0.025680             0.052624
# 10                                  0.061160  0.046670             0.082388
# 11                                  0.043167  0.069849             0.085810
# 12                                  0.057307 -0.023710             0.012320
# 13                                  0.051506  0.024903             0.021724
# 14                                  0.051214  0.025680             0.052624
# 15                                  0.061160  0.046670             0.082388
# 16                                  0.043167  0.069849             0.085810
# 17                                  0.057307 -0.023710             0.012320
# 18                                  0.051506  0.024903             0.021724
# 19                                  0.051214  0.025680             0.052624
# 20                                  0.061160  0.046670             0.082388
# 21                                  0.043167  0.069849             0.085810
# 22                                  0.057307 -0.023710             0.012320
# 23                                  0.051506  0.024903             0.021724
# 24                                  0.051214  0.025680             0.052624
# 25                                  0.061160  0.046670             0.082388
# 26                                  0.043167  0.069849             0.085810
# 27                                  0.057307 -0.023710             0.012320
# 28                                  0.051506  0.024903             0.021724
# 29                                  0.051214  0.025680             0.052624
# 30                                  0.061160  0.046670             0.082388
# 31                                  0.043167  0.069849             0.085810
# 32                                  0.057307 -0.023710             0.012320
# 33                                  0.051506  0.024903             0.021724
# 34                                  0.051214  0.025680             0.052624
#
#     KMERscale_no_clr  KMERno_scale_clr  KMERscale_clr  KMERcenter_no_clr  \
# 0           0.031877          0.056173       0.005031           0.072775
# 1           0.072354          0.057956       0.017804           0.081095
# 2          -0.002134          0.049193      -0.006661           0.027244
# 3           0.055003          0.043871       0.010904           0.043497
# 4           0.057796          0.038733       0.047703           0.070535
# 5           0.031877          0.056173       0.005031           0.072775
# 6           0.072354          0.057956       0.017804           0.081095
# 7          -0.002134          0.049193      -0.006661           0.027244
# 8           0.055003          0.043871       0.010904           0.043497
# 9           0.057796          0.038733       0.047703           0.070535
# 10          0.031877          0.056173       0.005031           0.072775
# 11          0.072354          0.057956       0.017804           0.081095
# 12         -0.002134          0.049193      -0.006661           0.027244
# 13          0.055003          0.043871       0.010904           0.043497
# 14          0.057796          0.038733       0.047703           0.070535
# 15          0.031877          0.056173       0.005031           0.072775
# 16          0.072354          0.057956       0.017804           0.081095
# 17         -0.002134          0.049193      -0.006661           0.027244
# 18          0.055003          0.043871       0.010904           0.043497
# 19          0.057796          0.038733       0.047703           0.070535
# 20          0.031877          0.056173       0.005031           0.072775
# 21          0.072354          0.057956       0.017804           0.081095
# 22         -0.002134          0.049193      -0.006661           0.027244
# 23          0.055003          0.043871       0.010904           0.043497
# 24          0.057796          0.038733       0.047703           0.070535
# 25          0.031877          0.056173       0.005031           0.072775
# 26          0.072354          0.057956       0.017804           0.081095
# 27         -0.002134          0.049193      -0.006661           0.027244
# 28          0.055003          0.043871       0.010904           0.043497
# 29          0.057796          0.038733       0.047703           0.070535
# 30          0.031877          0.056173       0.005031           0.072775
# 31          0.072354          0.057956       0.017804           0.081095
# 32         -0.002134          0.049193      -0.006661           0.027244
# 33          0.055003          0.043871       0.010904           0.043497
# 34          0.057796          0.038733       0.047703           0.070535
#
#     KMERcenter_clr
# 0        -0.012291
# 1         0.032632
# 2         0.117702
# 3         0.041907
# 4         0.016039
# 5        -0.012291
# 6         0.032632
# 7         0.117702
# 8         0.041907
# 9         0.016039
# 10       -0.012291
# 11        0.032632
# 12        0.117702
# 13        0.041907
# 14        0.016039
# 15       -0.012291
# 16        0.032632
# 17        0.117702
# 18        0.041907
# 19        0.016039
# 20       -0.012291
# 21        0.032632
# 22        0.117702
# 23        0.041907
# 24        0.016039
# 25       -0.012291
# 26        0.032632
# 27        0.117702
# 28        0.041907
# 29        0.016039
# 30       -0.012291
# 31        0.032632
# 32        0.117702
# 33        0.041907
# 34        0.016039

# %%
select_columns_bool = True

# %%
# ['6-mers norm', '6-mers no_scale_clr','6-mers scale_clr','7-mers norm','7-mers no_scale_clr','7-mers scale_clr']
# ['6-mers Raw', '6-mers MINVERVA','6-mers MINERVA-scale', '7-mers Raw','7-mers MINVERVA','7-mers MINVERVA-scale']
# Make boxplot for one group only

select_columns = ['OTUraw','OTUbmc','OTUComBat','OTUlimma',
                                 'OTUclr_pca_regress_out_no_scale',"KMERnorm","KMERno_scale_clr"]
select_labels = ['OTU raw','OTU BMC','OTU ComBat','OTU limma',"OTU MINERVA","K-mer raw", "K-mer MINERVA"]


# ['OTU raw','OTU BMC','OTU ComBat','OTU limma',
#                                      "K-mer raw","K-mer ComBat","K-mer smartsva*",
#                                     "K-mer MINERVA"]
if select_columns_bool:
    g=sns.boxplot( data = df_metric[select_columns])
    g.set_xticklabels(rotation=90,labels = select_labels) #df_metric.columns
else:
    g=sns.boxplot( data = df_metric)
    g.set_xticklabels(rotation=90,labels = df_metric.columns)
    
g.set_title(title)
plt.savefig(plot_folder + 'boxplots_' + classifier + '_' + metric_word + '.pdf',bbox_inches='tight')
plt.savefig(plot_folder + 'boxplots_' + classifier + '_' + metric_word +'.png',bbox_inches='tight')

# %%
current_palette = sns.color_palette()
#sns.palplot(current_palette)
palette = sns.color_palette("hls", len(select_columns))
plot_color = palette.as_hex()
